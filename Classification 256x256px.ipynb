# %% [markdown]
# # Kuzushiji Classification with fastai

# %%
# %matplotlib inline
from fastai.vision import *
from tqdm import tqdm_notebook as tqdm
import stable.utils

# %%
stable.utils.group_valid_split()

# %%
path = Path("data")
train_fnames = (path/"train_fnames.txt").read_text().split("\n")
valid_fnames = (path/"valid_fnames.txt").read_text().split("\n")
df_train = pd.read_csv(path/"train.csv")
unicode_map = {codepoint: char for codepoint, char in pd.read_csv('data/unicode_translation.csv').values}

# %% [markdown]
# ## Create training data (256x256 pixel context around center point)
#
# Instead of predicting the size of characters like in K_mat's kernel, we just train the classifier to deal with 256x256 pixel area. This skips regressing bounding box coordinates.

# %%
#!rm -r data/train_images_chars_256/

# %%
def create_classification_train_data(path, df_train, train_fnames, valid_fnames, bg_class=True, n_bg_examples_per_page=20):
    # Was error with char_is_valid, hopefully fixed now
    char_fnames = []
    char_labels = []
    char_is_valid = []

    save_path = path/"train_images_chars_256"

    if not save_path.exists():
        save_path.mkdir()

    R = 128  # 256 // 2

    for _, row in tqdm(df_train.iterrows()):
        im = np.array(PIL.Image.open(path/"train_images"/(row.image_id+".jpg")))
        labels = row.labels
        if type(labels) == float and math.isnan(labels):
            # No characters in this page
            if bg_class == True:
                # Create negative examples
                height, width = im.shape[:2]
                x_centers = np.random.randint(R, width - R, size=n_bg_examples_per_page)
                y_centers = np.random.randint(R, height - R, size=n_bg_examples_per_page)
                for i in range(n_bg_examples_per_page):
                    x0, y0, x1, y1 = x_centers[i] - R, y_centers[i] - R, x_centers[i] + R, y_centers[i] + R
                    im_char = PIL.Image.fromarray(im[y0:y1, x0:x1])
                    fname = row.image_id + "_" + str(i).zfill(4) + ".jpg"
                    char_fnames.append(fname)
                    char_labels.append("BACKGROUND")
                    im_char.save(save_path/fname)
                    if row.image_id in train_fnames:
                        char_is_valid.append(False)
                    else:
                        char_is_valid.append(True)
        else:
            labels_split = labels.split(" ")
            classes = [labels_split[i] for i in range(0, len(labels_split), 5)]
            bboxes = [list(map(int, labels_split[i+1:i+5])) for i in range(0, len(labels_split), 5)]

            for i in range(len(classes)):
                label = classes[i]
                x, y, width, height = bboxes[i]
                center_x = x + width // 2
                center_y = y + height // 2
                x0, y0 = max(0, center_x - R), max(0, center_y - R)
                x1, y1 = center_x + R, center_y + R
                im_char = PIL.Image.fromarray(im[y0:y1, x0:x1])
                fname = row.image_id + "_" + str(i).zfill(4) + ".jpg"
                char_fnames.append(fname)
                char_labels.append(label)
                im_char.save(save_path/fname)
                if row.image_id in train_fnames:
                    char_is_valid.append(False)
                else:
                    char_is_valid.append(True)
                    
    chars_df = pd.DataFrame(np.array([char_fnames, char_labels]).transpose(), columns=["filename", "label"])
    chars_df["is_valid"] = char_is_valid
    chars_df.to_csv(path/"train_chars_256.csv", index=False)

# %%
create_classification_train_data(path, df_train, train_fnames, valid_fnames, bg_class=True)
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-370ac12ce059> in <module>
# ----> 1 create_classification_train_data(path, df_train, train_fnames, valid_fnames, bg_class=True)
#
# <ipython-input-5-94c6e141bc98> in create_classification_train_data(path, df_train, train_fnames, valid_fnames, bg_class, n_bg_examples_per_page)
#      45                 x0, y0 = max(0, center_x - R), max(0, center_y - R)
#      46                 x1, y1 = center_x + R, center_y + R
# ---> 47                 im_char = PIL.Image.fromarray(im[y0:y1, x0:x1])
#      48                 fname = row.image_id + "_" + str(i).zfill(4) + ".jpg"
#      49                 char_fnames.append(fname)
#
# ~/anaconda3/envs/fastai/lib/python3.7/site-packages/PIL/Image.py in fromarray(obj, mode)
#    2668             obj = obj.tostring()
#    2669
# -> 2670     return frombuffer(mode, size, obj, "raw", rawmode, 0, 1)
#    2671
#    2672
#
# ~/anaconda3/envs/fastai/lib/python3.7/site-packages/PIL/Image.py in frombuffer(mode, size, data, decoder_name, *args)
#    2611             return im
#    2612
# -> 2613     return frombytes(mode, size, data, decoder_name, args)
#    2614
#    2615
#
# ~/anaconda3/envs/fastai/lib/python3.7/site-packages/PIL/Image.py in frombytes(mode, size, data, decoder_name, *args)
#    2544
#    2545     im = new(mode, size)
# -> 2546     im.frombytes(data, decoder_name, args)
#    2547     return im
#    2548
#
# ~/anaconda3/envs/fastai/lib/python3.7/site-packages/PIL/Image.py in frombytes(self, data, decoder_name, *args)
#     828         d = _getdecoder(self.mode, decoder_name, args)
#     829         d.setimage(self.im)
# --> 830         s = d.decode(data)
#     831
#     832         if s[0] >= 0:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Train resnet18 classifier

# %%
chars_df = pd.read_csv(path/"train_chars_256.csv")

# %%
data = (ImageList.from_df(chars_df, path/"train_images_chars_256")
        .split_from_df("is_valid")
        .label_from_df("label", classes=list(set(chars_df["label"])))
        .transform(get_transforms(do_flip=False), size=(128,128))
        .databunch(bs=256)
        .normalize(imagenet_stats)
       )

# %%
data.show_batch(3)

# %%
learn = cnn_learner(data, models.resnet18, metrics=[accuracy],
                    callback_fns=[#callbacks.ReduceLROnPlateauCallback,
                                  ShowGraph
                                 ]).mixup().to_fp16()

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(10, slice(1e-2))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.214666</td>
#       <td>3.210932</td>
#       <td>0.366177</td>
#       <td>07:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.373975</td>
#       <td>2.011513</td>
#       <td>0.602890</td>
#       <td>07:14</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.156946</td>
#       <td>1.754955</td>
#       <td>0.659455</td>
#       <td>07:22</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.073895</td>
#       <td>1.600126</td>
#       <td>0.687203</td>
#       <td>07:29</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.986665</td>
#       <td>1.524132</td>
#       <td>0.704544</td>
#       <td>07:28</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.894498</td>
#       <td>1.430151</td>
#       <td>0.725695</td>
#       <td>07:31</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.842145</td>
#       <td>1.348746</td>
#       <td>0.740302</td>
#       <td>07:18</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>2.757540</td>
#       <td>1.297702</td>
#       <td>0.751574</td>
#       <td>07:11</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>2.695991</td>
#       <td>1.259189</td>
#       <td>0.759389</td>
#       <td>07:10</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>2.684417</td>
#       <td>1.252283</td>
#       <td>0.760730</td>
#       <td>07:12</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(30, slice(2e-2))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.322710</td>
#       <td>1.005170</td>
#       <td>0.811668</td>
#       <td>07:27</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.164593</td>
#       <td>0.977651</td>
#       <td>0.826451</td>
#       <td>07:26</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.088961</td>
#       <td>0.840365</td>
#       <td>0.828673</td>
#       <td>07:24</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.037723</td>
#       <td>0.842673</td>
#       <td>0.835333</td>
#       <td>07:23</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2